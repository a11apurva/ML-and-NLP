# %% [markdown]
# ## K-means on word2vec embeddings

# %%
from gensim.models import Word2Vec
model = Word2Vec.load("300features_10minwords_10context")
# Out:
# C:\Users\apurva\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\utils.py:862: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
print(type(model.wv.syn0))
print(model.wv.syn0.shape)
#model["volumes"]
print(len(model.wv.vocab))
# Out:
# <class 'numpy.ndarray'>
# (14044, 300)
# 14044

# %%
from sklearn.cluster import KMeans
import time

start = time.time()

# %%
word_vectors = model.wv.syn0
num_clusters = int(word_vectors.shape[0] / 100)

# Initalize a k-means object and use it to extract centroids
kmeans_clustering = KMeans( n_clusters = num_clusters )
idx = kmeans_clustering.fit_predict( word_vectors )

# Get the end time and print how long the process took
end = time.time()
elapsed = end - start
print("Time taken for K Means clustering: ", elapsed, "seconds.")
# Out:
# Time taken for K Means clustering:  4105.84792137146 seconds.

# %%
word_centroid_map = dict(zip( model.wv.index2word, idx ))

print(len(word_centroid_map.values()))
val=list(word_centroid_map.values())
key=list(word_centroid_map.keys())
print(len(val))
print(len(key))
# Out:
# 14044
# 14044
# 14044

# %%
for cluster in range(0,100):
    #
    # Print the cluster number  
    print("\nCluster %d" % cluster)
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for i in range(0,len(word_centroid_map.values())):
        if( val[i] == cluster ):
          words.append(key[i])
    print(words)
# Out:
# Cluster 0
# ['one', 'like', 'also', 'since', 'could', 'problem', 'would', 'different', 'sure', 'seems', 'think', 'going', 'something', 'however', 'good', 'well', 'way', 'even', 'appears', 'possible', 'might', 'either', 'right', 'likely', 'believe', 'anything', 'probably', 'though', 'much', 'actually', 'seem', 'really', 'longer', 'nothing', 'means', 'problems', 'question', 'lot', 'tell', 'given', 'least', 'place', 'happening', 'else', 'fine', 'things', 'thing', 'example', 'maybe', 'say', 'particular', 'fact', 'suspect', 'figure', 'quite', 'timing', 'others', 'makes', 'thought', 'mean', 'unfortunately', 'guess', 'past', 'away', 'exactly', 'little', 'pretty', 'perhaps', 'chance', 'possibly', 'except', 'explain', 'although', 'don', 'somehow', 'ones', 'interesting', 'assume', 'idea', 'completely', 'apparently', 'kind', 'usually', 'anyway', 'basically', 'often', 'stuff', 'strange', 'assuming', 'ever', 'saying', 'quickly', 'specifically', 'dont', 'evidence', 'perspective', 'anymore', 'worth', 'behind', 'difficult', 'theory', 'trouble', 'wondering', 'thinking', 'indication', 'moment', 'thinks', 'reasons', 'somewhere', 'especially', 'matter', 'unlikely', 'neither', 'slightly', 'concern', 'confused', 'deal', 'giving', 'doesn', 'weird', 'course', 'whatever', 'remains', 'reasonable', 'fairly', 'okay', 'obvious', 'definitely', 'wonder', 'symptoms', 'behaviour', 'concerned', 'we', 'lack', 'didn', 'hand', 'presumably', 'unrelated', 'guessing', 'explains', 'unusual', 'certainly', 'near', 'confusing', 'ways', 'knows', 'whereas', 'worse', 'tells', 'obviously', 'generally', 'recall', 'highly', 'doesnt', 'somebody', 'dealing', 'interaction', 'somewhat', 'curious', 'isn', 'thats', 'pinlds', 'didnt', 'gotten', 'digging', 'culprit', 'spot', 'apparent', 'particularly', 'suspicion', 'figured', 'whats', 'respect', 'that', 'suddenly', 'ultimately', 'behaving', 'behaves', 'latter', 'occasionally', 'worry', 'harder', 'presume', 'surface', 'contributed', 'seriously', 'surprised', 'exhibiting', 'shouldnt', 'slowing', 'sane', 'trusted', 'rapidly', 'skeptical', 'instability']
#
# Cluster 1
# ['src', 'req', 'dest', 'bounds', 'ref', 'align', 'reftag', 'sign', 'misc', 'ea_cpy_req_t', 'ea_cpy', 'bdev_vvol', 'cpy', 'ecp_error', 'ecp_src', 'cor', 'where_id', 'pm_cmp', 'aligned_address', 'align_size', 'ecp_des', 'erq_eapa', 'erq_va', 'ecp_cb', 'xcb_len', 'grd', 'total_len', 'dest_addr', 'harrier_xcb', 'ecp_nsrc', 'ecp_par_zret', 'flg', 'ecp_result', 'eagletest', 'ecp_zret', 'ecp_ndes', 'compr_lib', 'ecp_desnid', 'erq_flag', 'ea_req_list_t', 'cwi_sdt_cmnd_install', 'cwi_ld_alloc_zcmp', 'cwi_eapat_des_renew', 'cwi_save_some_cmps', 'cwi_ea_cmp_alloc', 'cwi_dds_gc_init', 'cwi_rmt_vio_init', 'accross', 'free_anon_lru_', 'excluding', 'pmem_anon_lru_length', 'rdsrv_t', 'reqd_cmps', 'erq_cmpdst', 'erq_dif_op', 'ecp_caller_stack', 'cwi_slog_binit_hdr', 'nlocal', 'rtotal', 'erq_dif_ref', 'ecp_cur_idx', 'do_compare_cmps', 'ecp_msg_type', 'reveals', 'xport', 'ecp_flag', 'ecp_msg', 'vm_struct', 'inbound', 'atomic_t', 'wno', 'xcb_t', 'ecp_link', 'num_sge', 'erq_dif_app', 'xor_or', 'evt_notify_log', 'src_addrs', 'ea_sg_copy', 'drq_flags_limitq', 'cmpr_cb', 'xcb_nsrc', 'deschk', 'ecp_src_addr', 'ecp_src_cur_idx', 'timer_interrupt', 'drq_flags_flusher', 'ecp_cb_arg', 'src_idx', 'ecp_dif', 'ecp_srcint_remaining', 'vr_curva', 'ea_cpy_req', 'xcb_rop']
#
# Cluster 2
# ['linux', 'com', 'client', 'tools', 'copyright', 'terms', 'license', 'updater', 'operating', 'tpdtcl', 'inc', 'subject', 'hpe', 'hewlett', 'gnu', 'warranty', 'conf', 'eula', 'corporation', 'distribution', 'debian', 'wsapi', 'programs', 'red', 'telnet', 'tcp', 'absolutely', 'hat', 'public', 'licensed', 'exclusion', 'menu', 'welcome', 'redistributable', 'freely', 'rights', 'cimserver', 'enterprise', 'doc', 'permitted', 'foundation', 'prep', 'japan', 'cim', 'clients', 'mission', 'audit', 'escape', 'modprobe', 'dar', 'auth', 'law', 'tab', 'roseville', 'stor', 'communications', 'lisa', 'dhcp', 'lan', 'desktop', 'click', 'spmaint', 'visit', 'esc', 'roger', 'credentials', 'swlist', 'yodlee', 'colorado', 'pub', 'demo', 'uname', 'emlxs', 'cbs', 'username', 'identifies', 'boxes', 'director', 'pack', 'sftp', 'fallback', 'mce', 'vpn', 'arrange', 'edition', 'consortium', 'udp', 'inbox', 'spdood', 'refreshed', 'rmsvc', 'zxf', 'sheet', 'computer', 'sunw', 'supportshow', 'spt', 'prerelease', 'connex', 'university', 'essn', 'assembled', 'citrix', 'spvar', 'infinity', 'switchlogs']
#
# Cluster 3
# ['pagin', 'emfc_confirm_rst', 'rec_replay_rep_ld', 'cmp_tick_loop_wait', 'rdsrv_active', 'cmp_invalid_vid', 'stores', 'uniqcrc', 'sdt_new_target', 'posts', 'holder', 'parity_list', 'prompted', 'modifed', 'ipc_cancel_request', 'staled', 'bother', 'cancels', 'expire', 'miscellaneous', 'refill', 'traverse', 'recv_range', 'deallocate', 'req_tag', 'hasnt', 'vvrm_work', 'unchecked', 'unlocking', 'rsets', 'slist', 'ipc_reply_error', 'nod', 'vvf_cls', 'reponse', 'loop_down', 'etl_mem', 'decompressed', 'reallocated', 'crossing', 'treating', 'drq_reinit', 'erroneous', 'is_degraded', 'vv_ndirty_cmp', 'calculates', 'hat_unload_excp', 'masking', 'acknowledged', 'modifies', 'release_version', 'fires', 'decreasing', 'terminates', 'cmp_abort_dcow', 'rewriting', 'prereads', 'sc_mc', 'tricky', 'madm_bmap', 'freelist', 'treats', 'holes', 'likewise', 'serialize', 'emfc_iocb_t', 'expanded', 'contexts', 'src_ldm', 'ld_backup', 'scsi_target_t', 'jobs', 'foreground', 'iterator', 'pdcmd_scrub', 'fcp_data_length', 'infomation', 'ld_updating', 'reqd_mem', 'ld_blocks', 'walked', 'remapped', 'mlist', 'cerner', 'mbmap_busy', 'implying', 'cmp_rmt_owned', 'transit', 'emh_loop_down', 'read_rev', 'is_tachy_wwn', 'gfc_rism', 'cex_cfg_flags', 'ipc_node_up', 'sticks', 'decrements', 'ld_id', 'vvi_rcm_nxt', 'synchronously', 'lpi_les', 'dds_vhdr', 'ioctl_call_timed', 'fake_crc_calc', 'vv_is_closed', 'wraps', 'parities', 'ld_activeio', 'maxto', 'pfsv_badvv_buf', 'prcheck', 'ic_no_tl', 'populating', 'zdcow', 'compr_cow_info', 'excp_flusher_wait', 'rb_cmp_msk', 'redefine', 'keepld', 'mpg_state', 'vvol_define', 'logpages', 'retv', 'preemptive', 'sc_aborting', 'set_ldck', 'cmnd_state_t', 'process_snap', 'sdt_unbind_target', 'si_mtx', 'infact', 'cfc_max', 'vi_vvhdr', 'forcefully', 'systemvirtvols', 'unreg', 'representing', 'honor', 'masters', 'entires', 'vi_refcnt', 'vvol_ssr', 'unmarked', 'proc_els_thread', 'unreg_all', 'task_mtx', 'dc_palist', 'paragraph', 'sc_hba', 'refactoring', 'chinit_debug', 'taglog_enabled', 'stlookup', 'eaq_state_recv', 'pmap_get_id', 'compleakcheck', 'vio_priv', 'revisited', 'reusing', 'optimizations', 'serialized', 'cahce', 'wil', 'recognizable', 'reclaimable', 'readers', 'fulldefined', 'vv_blk_dedup', 'bdev_vvolcm_cmp', 'proc_lp', 'mbmap_nxt', 'kerne', 'enqueue', 'prudent', 'thread_info', 'dc_drq', 'mclp_param', 'tha', 'ld_barrierlist', 'ldcmd_newbk', 'ldck_work_list', 'currto', 'clus_hw_do_join', 'delayedabort', 'eagle_en_send_msgq', 'lsc_blk_data']
#
# Cluster 4
# ['vhdr', 'adm', 'lvl', 'idx', 'excp', 'bid', 'family', 'vvid', 'pgin', 'dcmp', 'maps', 'crcs', 'vtte', 'ddd', 'dexcp', 'nread', 'nwrite', 'sttes', 'scanned', 'dds_vv', 'walk', 'bvv', 'ind', 'vv_name', 'mbmap', 'vvol_t', 'rwss', 'dsk', 'hatstat', 'dbase', 'zerold', 'leaf', 'vvdmap', 'vol', 'fixable', 'dptp', 'belonging', 'del', 'v_shared_cpg', 'bva', 'dskoff', 'ercnt', 'nfercnt', 'stat_ercnt', 'excp_ercnt', 'get_ptbl', 'vvol_define_callback', 'exch', 'compr_gc_srv', 'do_get_ptbl', 'walk_ptbl', 'epage', 'rwlock', 'vv_mangler_id', '__sd', 'vv_ndblk', 'convention', 'wrtbk', 'vdsk', 'checkvvs', 'venkataraman', 'expect_fix', 'compressid', 'lotts', 'regmv', 'vv_odblk', 'tbl', 'vvf_no_pgin', 'claim_excp_page', 'pvv', 'ace_fp', 'scn', 'vhdrs', 'adm_pgin_valc_pgs', 'mpg_busy', 'drop_adm', 'vvsa', 'dds_id', 'vvf_no_meta', 'rochild', 'lfp', 'compr_idx', 'mangler_id', 'ss_vv_list']
#
# Cluster 5
# ['issue', 'please', 'get', 'need', 'take', 'know', 'reproduce', 'try', 'able', 'let', 'help', 'needed', 'want', 'working', 'enough', 'provide', 'confirm', 'best', 'keep', 'understand', 'soon', 'whether', 'determine', 'someone', 'investigate', 'give', 'investigation', 'lab', 'machine', 'debugging', 'leave', 'ask', 'otherwise', 'quick', 'unless', 'reproducible', 'answer', 'suggest', 'useful', 'tomorrow', 'decided', 'asking', 'recreate', 'live', 'repro', 'it', 'feel', 'identify', 'told', 'wanted', 'decide', 'easily', 'understanding', 'easy', 'investigating', 'together', 'hopefully', 'remember', 'hope', 'wants', 'important', 'regards', 'reproducing', 'talk', 'dinesh', 'sufficient', 'helpful', 'anyone', 'experiment', 'btw', 'keeping', 'effort', 'instructions', 'happy', 'late', 'forgot', 'helps', 'guys', 'mind', 'meanwhile', 'easier', 'interested', 'great', 'instrumentation', 'light', 'focus', 'meantime', 'managed', 'suppose', 'nice', 'solve', 'wish', 'knowledge', 'decision', 'cant', 'people', 'thoughts', 'prove', 'grant', 'clue', 'believes', 'house', 'can', 'poa', 'dig', 'narrow', 'hoping', 'efforts', 'wont', 'opinion', 'madhu', 'appreciate', 'reliably', 'unclear', 'hear', 'towards', 'outcome', 'ideas', 'unsure', 'agrees', 'helped', 'instrumented', 'isolate', 'reliable', 'suggestions', 'insight', 'diagnose', 'here', 'assess', 'appreciated', 'careful', 'troubleshoot', 'diagnosis', 'pursue', 'what', 'learned', 'clearer', 'emma', 'hurt', 'worthwhile', 'tejas', 'vaguely', 'chase', 'reoccurs', 'permutations', 'bear']
#
# Cluster 6
# ['object', 'format', 'partition', 'binary', 'image', 'hex', 'analyzed', 'identical', 'services', 'content', 'revision', 'individual', 'iotrace', 'objects', 'symbol', 'utility', 'dedupdu', 'unlimited', 'pcfg', 'symbols', 'deletions', 'insertions', 'erase', 'compatible', 'retrieved', 'descriptors', 'filename', 'downloading', 'churn', 'staging', 'scsi_db', 'scsidb', 'rtamma', 'compile', 'fwdb', 'load_nemoe', 'altering', 'rom', 'lcrash', 'cpp', 'floor', 'digit', 'centos', 'qtstatus', 'dlfw', 'dumpfile', 'cpua', 'libraries', 'awc', 'cpub', 'datagen', 'sr_mnt', 'xml', 'acfg', 'ora', 'cerrs', 'jessie', 'umod', 'certificates', 'encrypting', 'frul_bypass', 'evt_types_version', 'flat', 'ksyms', 'firmwaredb', 'sourced', 'blocksizes', 'vfs', 'crap', 'ahh', 'aliasing', 'hgstbgscan']
#
# Cluster 7
# ['root', 'name', 'clwait', 'showversion', 'agrep', 'greenblnk', 'showsysmgr', 'totalcap', 'freecap', 'alloccap', 'failedcap', 'shownode', 'showsys', 'showhost', 'clusterled', 'showcage', 'bash', 'showalert', 'verp', 'showrcopy', 'rsh', 'showrsv', 'amberblnk', 'password', 'broadcast', 'lrwxrwxrwx', 'pts', 'showpdata', 'showeeprom', 'tailsys', 'showfirmwaredb', 'oot', 'nohup', 'showmemval', 'rtpd', 'mvar_set', 'kgrep', 'emfw', 'enodeced', 'load_tpd', 'tcpdump', 'mcinj_reset', 'foreign', 'gdbinit', 'showbattery', 'showflashcache', 'ssmssm', 'shownet', 'nerror', 'checkport', 'endpoint', 'showpatch', 'elvis', 'nodegc', 'tpvv_source', 'retaining', 'instructed', 'ignoretask', 'showfs', 'fsnode', 'bondmode', 'ifconfig', 'mahler', 'clstate', 'rlogin', 'gethost', 'testreadl', 'corecat', 'controliscsiport', 'installtime', 'lsattr']
#
# Cluster 8
# ['base', 'step', 'dedup', 'tpvv', 'volumes', 'create', 'tdvv', 'non', 'compression', 'created', 'promote', 'snaptest', 'cpg', 'teststep', 'snapshot', 'compressed', 'snap', 'removing', 'snapshots', 'random', 'cpvv', 'creating', 'tdvvs', 'snaps', 'conversion', 'vluns', 'tpvvs', 'tune', 'conversions', 'provisioned', 'deco', 'delete', 'background', 'creation', 'parent', 'export', 'convert', 'cpgs', 'thin', 'converting', 'copies', 'randomly', 'dedupe', 'compress', 'creates', 'provisioning', 'regions', 'mix', 'importvv', 'workloadmanager', 'vvcopy', 'tunes', 'deleting', 'converted', 'tunesys', 'ddr', 'promotes', 'provision', 'thinly', 'removes', 'compactcpg', 'estimation', 'cpvvs', 'produced', 'mover', 'deduped', 'movement', 'updatevv', 'exports', 'grows', 'simultaneously', 'importing', 'powerfails', 'imports', 'tuned', 'thermite', 'createvvcopy', 'pcopy', 'promotesv', 'zero_detect', 'vdisks', 'grown', 'vols', 'exporting', 'dismiss', 'tpvvc', 'vvsets', 'dry_run', 'vv', 'svs', 'getprov', 'imported', 'selecting', 'vvcreation', 'flavor', 'fpg', 'reclaiming', 'deletes', 'mixture', 'tpcvv', 'bulkio', 'grew', 'schedules', 'fat', 'tdcvv', 'promotion', 'resyncs', 'promoting', 'slected', 'createthin', 'datastore', 'cdr', 'creations', 'admitvv', 'shots', 'tdvvc', 'varying', 'autogrow', 'creategroupvvcopy', 'estimator', 'round_robin', 'rowsize', 'hostwrites', 'compacted', 'createsnaps', 'compacts', 'vvcopies', 'intrusive', 'reclaims', 'efficiently', 'vvtype', 'createvluns']
#
# Cluster 9
# ['dart', 'unstarted', 'rmmup', 'miscomparetype', 'pfail_val', 'shellcmd', 'iterated', 'gcc', 'listcols', 'nanocron', 'sblk_hdr', 'onlooped', 'sblk_crc', 'wrapper', 'trl', 'vanhalen', 'vol_init_log_beg', 'designated', 'xnodedcc', 'mlock', 'paxton', 'rcp', 'liststaged', 'checkserial', 'clustershutdown', 'drwx', 'noirq', 'rodata', 'hostmap', 'vlunmap', 'dump_all_cmps', 'postupgrade', 'sdt_bind_target', 'paramiko', 'otal', 'removealert', 'henry', 'rebootallnodepairs', 'hostsets', 'vvlist', 'benny', 'manby', 'eaglemir', 'timeout_onretry', 'ecdsa', 'sucessfully', 'rebootnode', 'nslogctl', 'moo', 'invalid_media', 'rmlink', 'koch', 'scratchy', 'buildinfo', 'removeflashcache', 'fastwrite', 'ans', 'whacking', 'expectedfailure', 'cgcmd', 'purple', 'sled', 'datamoveradmck', 'parserunlog', 'atom_test', 'prince', 'qw_test', 'altdev', 'hdisk', 'snodede', 'dtd_tester', 'sloglds', 'volname', 'quotes', 'expectedmiscompare', 'nodereboot', 'test_tunepd', 'bigtpvv', 'muntz', 'descriptions', 'miscomparefound', 'testlogs', 'hte', 'polyserv', 'couldnt', 'binaries', 'lrr', 'drive_hardreset', 'shutdownrandomnode', 'load_nl', 'reflash', 'lunreset', 'sgt', 'turbo_reset', 'lilo', 'conducted', 'merges', 'wit', 'zd_writesame', 'discrepancies', 'repairs', 'tgp', 'cnodeaa', 'single_platform', 'xnodedcd', 'clus', 'bigcpvv', 'softlock', 'vvol_flush', 'admitrcopyvv', 'ldrgsampler', 'notifie', 'incidence', 'issnapiostalled', 'mpath', 'deliberate', 'oittsm', 'commencing', 'all_tests', 'cage_powercycle', 'novcn', 'offlines', 'jluo', 'port_offline_node', 'bricked', 'cupertino', 'b_set', 'sherryr', 'update_tpd', 'jmurphy', 'admsnoop', 'pdsld', 'recoveries', 'disable_hugepages', 'ruble', 'bug_dir', 'powerdown', 'helper_misc', 'events_al', 'snmptrap', 'dirs', 'experimental', 'sysmgr_inject', 'kern_inject', 'nodepct', 'createvvs', 'arranged', 'midnight', 'cva', 'ehp', 'fcswitch', 'hrunning', 'stn', 'test_createaldvv', 'egcs', 'narinder', 'wear_level', 'nodeinterlinkfaults', 'stresswrap', 'exprot']
#
# Cluster 10
# ['case', 'due', 'cause', 'already', 'caused', 'result', 'clear', 'part', 'handling', 'happens', 'happen', 'cases', 'avoid', 'causing', 'correctly', 'causes', 'occurs', 'cleared', 'always', 'prevent', 'scenario', 'occur', 'previously', 'double', 'operations', 'properly', 'situation', 'detect', 'thus', 'therefore', 'hence', 'window', 'supposed', 'handled', 'race', 'potential', 'upon', 'incorrectly', 'clearing', 'subsequent', 'resulting', 'lead', 'sometimes', 'leading', 'detects', 'possibility', 'detection', 'preventing', 'shall', 'essentially', 'leads', 'designed', 'turns', 'lose', 'prevents', 'words', 'triggers', 'treat', 'underlying', 'triggering', 'rare', 'transient', 'simulate', 'implies', 'manner', 'saves', 'initiate', 'miss', 'clears', 'detecting', 'circumstances', 'leaves', 'redundant', 'occuring', 'consequence', 'corner', 'hole', 'positive', 'gracefully', 'throw', 'silent', 'involving', 'malformed', 'pinning', 'validating', 'flagged', 'unfortunate', 'precise', 'harm', 'purposely', 'harmless', 'thereby', 'errored', 'artifact', 'catching', 'complains', 'artificially', 'defensive', 'face', 'wind', 'accumulation', 'eliminating', 'graceful', 'notices', 'issuer', 'compromised', 'unit_attention', 'unreliable']
#
# Cluster 11
# ['host', 'inserv', 'server', 'hosts', 'switch', 'qlogic', 'connect', 'persona', 'fabric', 'esx', 'iscsi', 'aix', 'storage', 'windows', 'vmware', 'legacy', 'direct', 'solaris', 'generic', 'servers', 'brocade', 'connectivity', 'mpio', 'switches', 'database', 'zone', 'cisco', 'initiators', 'hpux', 'san', 'connections', 'configure', 'ibm', 'fcoe', 'matrix', 'microsoft', 'application', 'vms', 'veritas', 'machines', 'alua', 'configurations', 'box', 'rescan', 'agent', 'personas', 'mcdata', 'oracle', 'robin', 'redhat', 'npiv', 'cast', 'zoned', 'zones', 'mscs', 'fcip', 'emc', 'multipathing', 'applications', 'cfgadm', 'blue', 'egenera', 'sparc', 'rhel', 'clustering', 'apcon', 'esxi', 'blade', 'dmp', 'maint', 'ioscan', 'migrate', 'netapp', 'world', 'luxadm', 'unusable', 'cert', 'sql', 'odm', 'vsa', 'vmotion', 'party', 'cfgmgr', 'mpxio', 'win', 'queries', 'ucs', 'virtualization', 'dell', 'clustered', 'images', 'sessions', 'sles', 'fiber', 'odx', 'andes', 'appearing', 'adapters', 'administrator', 'suse', 'diagram', 'guest', 'ivr', 'sunos', 'explorer', 'uareplun', 'hacmp', 'agilent', 'reconfigured', 'cloning', 'storport', 'blades', 'multipathed', 'digits', 'pushback', 'bfs', 'onstor', 'gige', 'bed', 'vcenter', 'converter', 'pathing', 'powerha', 'alm', 'negotiate', 'fabrics', 'msdsm', 'vdi', 'esxcli', 'miniport', 'agents', 'dtm', 'gpfs', 'loosing', 'qla', 'oob', 'expansion', 'jni', 'rdm', 'ghost', 'ubuntu', 'herring', 'datastores', 'disconnects', 'risc', 'thier', 'mcho_setcap', 'workbench', 'activating']
#
# Cluster 12
# ['condition', 'wait', 'ready', 'integration', 'manager', 'checking', 'calling', 'integrated', 'waitforinitnodes', 'management', 'stdout', 'integrate', 'respond', 'persistent', 'form', 'responsive', 'healthy', 'lst_evt', 'health', 'continuing', 'rebuild', 'waitforsysmgrup', 'waitfornodeup', 'launcher', 'allnodes', 'transferring', 'alone', 'waitformgmtpipe', 'waitforinitdisks', 'deadnode_monitor', 'pfail_get_ide_info', 'thor', 'cmpleakcheck', 'haltlauncher', 'devtouchfilespresent', 'vvdict', 'clienthost', 'scsi_install', 'domains', 'collapse', 'instantiating', 'existence', 'vcs', 'matchsize', 'vvmasterids', 'clip', 'cpgdict', 'sysmanager', 'reform', 'pings', 'journalling', 'clienthostlist', 'getmasternode', 'waitsysmgrready', 'reachable', 'pinging', 'powerfailing', 'fencing', 'blinky', 'forms', 'manger', 'testfatalexception', 'logger', 'n_dwn', 'getcurrentdomains']
#
# Cluster 13
# ['class', 'responding', 'prompt', 'badnodeprompt', 'login', 'inform', 'cliutil', 'nobel', 'boole', 'carlson', 'packard', 'otis', 'turing', 'godel', 'sysrq', 'hoff', 'crashing', 'lamar', 'jacquard', 'zuse', 'benz', 'grove', 'gore', 'libby', 'wankel', 'jawhari', 'babbage', 'pullman', 'diesel', 'zap', 'midgely', 'judson', 'sikorsky', 'dunlop', 'ulhorn', 'gabor', 'quate', 'faggin', 'svc', 'thevenin', 'alcorn', 'valier', 'rubik', 'dickson', 'kepler', 'richter', 'yokoi', 'parry', 'fleming', 'urey', 'aiken', 'teller', 'singer', 'houdini', 'hopper', 'roper', 'swan', 'neumann', 'avalanche', 'hunley', 'incubus', 'fixx', 'sysreq', 'geiger', 'hertz', 'morse', 'skidrow', 'beatles', 'wirth', 'bacon', 'mills', 'wilkins', 'reconnected', 'rozier', 'curie', 'crick', 'ritchie', 'wright', 'yamaha', 'apgar', 'brattain', 'sucess', 'revertnode']
#
# Cluster 14
# ['nil', 'vio', 'dmsk', 'loff', 'pfn', 'lruq', 'dhdr', 'dcowp', 'rcnt', 'wcnt', 'lrun', 'lrup', 'vmsk', 'itick', 'flid', 'flush_flag', 'buddy', 'npair', 'zmsk', 'cmp_excl', 'wmsk', 'rmt', 'chash', 'itck', 'cmpcookie', 'hashlen', 'tlen', 'fcache', 'cmp_unlocked', 'soff', 'spl', 'phash', 'nchash', 'rnhd', 'eoff', 'cmp_bad_lruq', 'lru_ldwrt_hdr', 'cmp_rename', 'lru_pmem_clean', 'lru_ws_dev_hdr', 'mreboot', 'mem_loc', 'cmp_share', 'canfail', 'flush_max', 'lru_dcow_hdr', 'zero_cmp', 'bmsk', 'lru_wn_hdr', 'lru_dcow_proc_hdr', 'tnhd', 'vrfy_cmp_lock', 'bset', 'cmp_private', 'check_cmp_limits', 'stop_dev', 'data_addr_id', 'nxt_addr_id', 'rb_upper_limit', 'dcbp']
#
# Cluster 15
# ['max', 'sec', 'load', 'stats', 'cur', 'avg', 'average', 'min', 'iter', 'qlen', 'throughput', 'svt', 'iops', 'users', 'kbytes', 'iosz', 'press', 'statvlun', 'uptime', 'statport', 'sample', 'statvv', 'sum', 'statpd', 'watch', 'statcmp', 'svct', 'ave', 'statcpu', 'met', 'intervals', 'ctl', 'vesper', 'meminfo', 'btsecs', 'streams', 'sctimestats', 'iop', 'metric', 'dow', 'statld', 'nos', 'histogram', 'histpd', 'inits', 'srvvspace', 'drvsvtime', 'devsvtime', 'wbc', 'hostsum', 'dom', 'histvlun', 'createdby', 'vvsum', 'statlink', 'schedname', 'timecols', 'etsecs', 'averages', 'showfield']
# Cluster 16
# ['comment', 'real', 'reply', 'based', 'previous', 'original', 'looked', 'mentioned', 'reference', 'says', 'said', 'described', 'indicated', 'according', 'sorry', 'regarding', 'involved', 'confirmed', 'pointed', 'agree', 'missed', 'indeed', 'noted', 'identified', 'discovered', 'meant', 'sounds', 'determined', 'explanation', 'cover', 'stated', 'clearly', 'documented', 'investigated', 'confusion', 'explained', 'clarify', 'mistake', 'correction', 'referring', 'accurate', 'suggests', 'delivered', 'understood', 'typo', 'conclusion', 'clarification', 'resolving', 'accidentally', 'disregard', 'mentions', 'misleading', 'suspected', 'relating', 'outlined', 'believed', 'refers', 'emails', 'describes', 'relation', 'realized', 'independent', 'pasted', 'relates', 'aspect', 'directed', 'summarize', 'hypothesis', 'niall', 'proof', 'stating', 'referred', 'identifying', 'irrelevant', 'explaining', 'concerning', 'tam', 'absence', 'describing', 'interpret', 'continuation', 'fell', 'fortunately', 'autofix', 'debugged', 'kelly', 'producing', 'proves', 'evaluated', 'pressed', 'decent', 'casey', 'nevertheless', 'bowmore', 'conclusions', 'judging', 'intermediate', 'pasting', 'elevated', 'accident', 'highlight', 'dialogue']
#
# Cluster 17
# ['suited', 'revisit', 'pkg', 'exclude', 'atlas', 'hack', 'proto', 'satisfied', 'extensive', 'npi', 'patching', 'anytime', 'breaking', 'deciding', 'remainder', 'parm', 'breaks', 'technique', 'distinguish', 'accomplish', 'rings', 'implications', 'demonstrate', 'brett', 'cleaner', 'man', 'proved', 'alpha', 'grabbing', 'exclusively', 'bundled', 'bpt', 'propose', 'qualify', 'troy', 'proven', 'operate', 'differentiate', 'corrects', 'equipment', 'december', 'aid', 'tester', 'instrument', 'carefully', 'down_link', 'bcr', 'interim', 'adequate', 'deferring', 'readily', 'redesign', 'dependency', 'uncovered', 'proposing', 'pursuing', 'prompts', 'opens', 'comfortable', 'construct', 'whoever', 'exercised', 'refactored', 'training', 'inherent', 'fundamental', 'perfect', 'specifics', 'inadvertently', 'preference', 'flashing', 'opsource', 'introducing', 'safer', 'tweak', 'wording', 'enable_smart_warn', 'sdtcmd_prupdate', 'lengthy', 'standpoint', 'stoppdata', 'jae', 'liverpool', 'assigns', 'placeholder', 'reoccurrence', 'complexity', 'tweaks', 'suffice', 'introduction', 'retesting', 'cutoff', 'stock', 'pvr', 'untested', 'shortened', 'spots', 'reviews', 'preferable', 'variations', 'considerable', 'emergency', 'directions', 'brown', 'safest', 'empt', 'relaxes', 'testers', 'branches', 'repros', 'proving', 'overlooked', 'speeding', 'wrapping', 'freshly', 'dvt', 'pvt', 'confuses', 'imho', 'overdriven', 'iirc', 'rounds', 'swiss_osprey', 'comprscan', 'beside', 'cmp_swap_buffer', 'predict', 'consulted', 'ill', 'adjustments', 'ins', 'catches', 'dds_crc_bmap', 'demonstrates', 'unintended', 'buggy', 'redirect', 'titanx', 'declaration', 'flawed', 'lnk_rst', 'tweaking', 'commentary', 'correctness', 'tagging', 'simulator', 'variants', 'stubs', 'beneficial', 'safety', 'maintaining', 'suppressing', 'deploy', 'corrections']
#
# Cluster 18
# ['swapper', 'linked', 'rip', 'modules', 'threadinfo', 'rsp', 'romley', 'eflags', 'rax', '__dch', 'rbx', 'rdi', 'rcx', 'rsi', 'rbp', 'rdx', 'sysfs', 'stackpage', 'eip', 'pgd', 'tbd', 'pud', 'pmd', 'ebp', 'eflash', 'esi', 'eaipc_alloc_buff', 'denlow', 'dump_stack', 'esp', 'netcc', 'mov', 'child_rip', 'shutdown_thread', 'volatile', 'cpuset', 'error_exit', 'oom_adj', 'insmod', 'vfprintf', 'port_num', 'ecx', 'edi', 'oom_score_adj', 'inj_panic', 'eax', 'edx', 'killer', 'mwait_idle', 'fork', 'miner', 'rm_launcher', 'ebx', 'kdb_enter', 'compr_compl_thr', 'ijcmd_add', 'ksoftirqd', 'do_softirq', 'tpd_free_thr', 'kfree', 'ddd_dedup_handl', 'register_inj', 'mems_allowed', 'udevd', 'origeax', 'ea_msgcmd_timer', 'fedmgr', 'ocs_gfc_hal_wor', 'rmp_balance_thr', 'terry', 'ppv', 'xss', 'xcs', 'xds', 'xes', 'nr_', 'oomkilladj', 'show_trace']
#
# Cluster 19
# ['cmd', 'rpi', 'vpi', 'sdt', 'io_tag', 'ox_id', 'ctxt_tag', 'vv_id', 'vport', 'cx_id', 'ctx', 'ext', 'hal', 'blks', 'rx_id', 'def_rpi', 'd_id', 'ga_nxt', 'resp', 'scsi_status', 'unregistered', 'rval', 'addr_format', 'pl_len', 'ls_acc', 'prog_dbg', 'sd_scsi_id', 'out_ptr', 'oxid', 'in_hal', 'fcp_dl', 'iocb_hdr', 'tmf', 'scsi_cmnd_retry', 'sns', 'ffff', 'evt_print', 'e_d_tov', 'vnp_id', 'tag_type', 'sd_name', 'excep', 'r_a_tov', 'ctx_type', 'ocs_io', 'init_id', 'recved', 'ndbg', 'tstart', 'rw_lba', 'seq_id', 'iid', 'gfc_proc_rcv_abts', 'in_ptr', 'r_t_tov', 'hst', 's_id', 'enm', 'erp', 'io_hndl', 'rctl', 'sccmd_portop', 'abt_ctx', 'prev_io_hndl', 'rxid', 'bde_count', 'ba_acc', 'ioctx', 'iocb_field', 'hba_ioctl', 'err_code', 'err_ext_code', 'rpsm', 'rw_blks', 'read_vpi', 'vnp_status', 'ctio', 'sh_name', 'ex_status', 'eic', 'rnn_id', 'seq_cnt', 'vio_rsp_rmt_rd', 'reg_vpi', 'unreg_rport', 'rsp_sent', 'localreject', 'clsr', 'bde_addr', 'nodev', 'exchange_id']
#
# Cluster 20
# ['target', 'group', 'sync', 'groups', 'primary', 'secondary', 'async', 'periodic', 'rcpy', 'synced', 'ticket', 'mirroring', 'rcopy', 'dispenser', 'resync', 'role', 'css', 'mcrm_stop', 'syncstatus', 'mcrm_start', 'my_nid', 'localvv', 'remotevv', 'over_per_alert', 'rm_link_add', 'dtd', 'synchronization', 'rtis', 'rm_link_remove', 'roles', 'backlog', 'lastsynctime', 'witness', 'test_pp', 'sld', 'syncs', 'persistence', 'mcrm_check', 'synchronous', 'auto_recover', 'mirror_init', 'sync_ss', 'transparent', 'rm_vv_sync_cb', 'resync_ss', 'rcdv', 'enque', 'gid', 'vv_iter', 'r_iter', 's_iter', 'switchover', 'ticket_start', 'rmcmd_vv_config', 'qlength', 'snap_freq', 'psm', 'bwmgr', 'localusercpg', 'localsnapcpg', 'rmusercpg', 'rmsnapcpg', 'sssm', 'target_id', 'setrcopygroup', 'subsets', 'rpo', 'sw_rmm', 'rm_target_add', 'rm_hdr', 'mcrm_init', 'ticket_shutdown', 'rm_config_sys_init', 'rcopygroup', 'remoteconfig', 'mcrm_sync', 'calculatesynctime', 'remotecopy', 'event_rmm_link', 'lastsnaptime', 'css_id', 'rti_start_time', 'rm_config_start', 'rmt_mirror_init', 'rti_ptr', 'initsetup', 'syncrcopy', 'resubmit', 'clocks', 'numgroups', 'rm_clusseq_start_at', 'targetbc']
#
# Cluster 21
# ['hba', 'serial', 'emulex', 'arnold', 'slot', 'connected', 'hbas', 'lsi', 'card', 'helios', 'cages', 'replaced', 'cable', 'cards', 'replace', 'connects', 'replacement', 'pull', 'disconnected', 'series', 'slots', 'saturn', 'dual', 'connecting', 'lbod', 'inserted', 'pulled', 'cables', 'lbods', 'components', 'cabling', 'hot', 'kbods', 'dimms', 'tinman', 'mbod', 'swapped', 'plug', 'gem', 'pulling', 'sbod', 'mbods', 'problematic', 'physically', 'chassis', 'manufacturing', 'solid', 'sbods', 'plugged', 'center', 'swapping', 'backplane', 'bni', 'qualified', 'quad', 'pulls', 'dmag', 'inter', 'environmental', 'paired', 'pic', 'isolation', 'ups', 'negotiation', 'panel', 'behaviors', 'daisy', 'boards', 'kbod', 'fca', 'hooked', 'reseat', 'seated', 'plane', 'persist', 'enclosures', 'chamber', 'unconfigured', 'connectors', 'reseated', 'readings', 'lnk_state', 'toggling', 'mechanical', 'instantly', 'demonstrated', 'board_series', 'cabled']
#
# Cluster 22
# ['entry', 'vid', 'entries', 'lid', 'ptbl', 'logentry', 'rcmp', 'hash', 'pfpart', 'tte', 'voff', 'dtte', 'cookie', 'logentries', 'taglog', 'seqid', 'eapfn', 'cow_cmp', 'refbit', 'rep', 'cow', 'addrlo', 'addrhi', 'dumplogs', 'inv', 'dirty_cmp', 'ross', 'dmerge', 'pf_count', 'rw_dcow', 'pf_rnid', 'mod_tte', 'rb_cmp', 'rlgh_type', 'mod_dcow', 'ramlog', 'dirty_ld', 'out_lp', 'ttes', 'fmp', 'leapfn', 'ro_dcow', 'dirty_vv', 'ceapfn', 'rtag', 'rbmap', 'rlg_ty_cow_cmp', 'replayed', 'bmp_bid', 'bmp_stat', 'addrid', 'rb_rw_excp', 'adm_stat', 'relogged', 'rlog_remote', 'fcache_create', 'rlg_ty_dirty_cmp', 'rbmap_trans', 'dirty_mb', 'rlg_ty_del_free', 'refbits', 'cmp_info', 'rlg_ty_ro_dcow', 'rlg_ty_rw_dcow', 'add_vv_state_log', 'ldio_cnt', 'init_ptbl', 'rlg_ty_mod_tte', 'lgh_flag', 'sz_new', 'sz_old', 'replaying', 'vmas', 'inv_tte', 'rlg_ty_out_lp', 'lrc_rb', 'rb_limit', 'pri_flag', 'add_ptbl', 'rec_adm_del_free', 'hinfo', 'rb_lp', 'ro_cow', 'rec_cmp_info', 'rb_ro_dcow', 'rlg_ty_rbmap_trans', 'nextaddrid', 'pg_count', 'cow_ro', 'lesp', 'rb_ro_excp', 'rec_lists', 'dcow_zero_ro', 'pvtte', 'rb_rw_bmap', 'dpg_offset', 'rlg_ty_compr', 'trans', 'rlgtype']
#
# Cluster 23
# ['cli', 'showvv', 'vvname', 'execute', 'showld', 'select', 'createvv', 'nohdtot', 'showsysobjs', 'tunevv', 'csvtable', 'removevv', 'snp_cpg', 'usr_cpg', 'showcols', 'quit', 'keepvv', 'removevlun', 'vvpri', 'removesnap', 'createvlun', 'showvlun', 'createsv', 'setvv', 'removecpg', 'dedup_dryrun', 'vvset', 'pat', 'hidden', 'servicehost', 'showvvmap', 'run_cmd', 'pol', 'createvvset', 'updatesnapspace', 'createaldvv', 'movepd', 'cascade', 'compr_dryrun', 'administration', 'fixsd', 'matchbulkobjs', 'removeld', 'proc_cli_exec', 'nowait', 'testvv', 'migss', 'notree', 'syntax', 'movepdtospare', 'stoprcopygroup', 'createtpvv', 'setqos', 'createsched', 'dedup_stats', 'setcpg', 'saved_file', 'dedup_compr_dryrun', 'startrcopygroup', 'movereg', 'tunealdvv', 'creategroupsv', 'showdate', 'clrrsv', 'lvw', 'startvv', 'tunepd', 'sample_slowdisk', 'szu', 'returncode', 'rmsys', 'removevvset', 'tunetpvv', 'snodedcf', 'startpdata', 'vmkfstools', 'showldmap', 'tdvvoptimalstate', 'fixldraidset', 'dismissrcopylink', 'obtaining', 'showvvpd', 'clearstatus', 'vm_tpvv', 'no_zero_detect', 'srcpgspace', 'execclicmd', 'needs_maint_check', 'dstcpg', 'vmcpg']
#
# Cluster 24
# ['thread', 'threads', 'mcall', 'switching', 'libthread_db', 'lwp', 'xcopy', 'paging', 'popfsv', 'wakeup', 'nvdimm_monitor', 'tok', 'db_change', 'activated', 'registering', 'message_processor', 'mir', 'cachesvr_send_th', 'dispatching', 'worker', 'get_ns', 'dskfail', 'ddscan', 'dispatch', 'syncsizedisksinkb', 'spinlock', 'rm_receive', 'dio', 'event_stale_sv_rec', 'lite', 'roof', 'ipc_consume_thr', 'spawned', 'authentication', 'sock', 'toning', 'monitors', 'lbalengthpervv', 'pinld_flusher', 'rod', 'spawn', 'wakes', 'vvcmd_attach', 'ptrmap', 'iomax', 'inital', 'update_nvdimm_status', 'dispatched', 'endless', 'publickey', 'pdata_mgr_svthread', 'get_from_pool', 'rm_start_all_groups', 'rm_util_phase_exit', 'emfc_get_ns', 'serial_in']
#
# Cluster 25
# ['change', 'changed', 'level', 'make', 'work', 'needs', 'order', 'instead', 'behavior', 'must', 'specific', 'allow', 'updates', 'existing', 'better', 'ensure', 'rather', 'uses', 'including', 'works', 'simple', 'solution', 'forward', 'turn', 'making', 'generate', 'conditions', 'extra', 'necessary', 'directly', 'certain', 'along', 'effect', 'turned', 'various', 'modify', 'implemented', 'requires', 'design', 'mechanism', 'rtpg', 'implementation', 'drivers', 'simply', 'logic', 'special', 'proper', 'affect', 'throttle', 'safe', 'apply', 'purpose', 'algorithm', 'care', 'implement', 'allows', 'ignored', 'outside', 'generating', 'improve', 'break', 'intended', 'scenarios', 'regardless', 'calculation', 'ability', 'optimization', 'effects', 'capability', 'whenever', 'combination', 'immediate', 'involves', 'internally', 'approach', 'depends', 'considering', 'involve', 'recognize', 'explicitly', 'appropriately', 'eliminate', 'throttling', 'responsible', 'scheme', 'needing', 'treated', 'adds', 'straight', 'unnecessary', 'prefer', 'improved', 'rely', 'requiring', 'enhance', 'expectation', 'differently', 'behave', 'ensuring', 'preserve', 'duplication', 'picture', 'equivalent', 'maintain', 'dependent', 'elsewhere', 'presence', 'coded', 'phases', 'friendly', 'opposed', 'depend', 'alternative', 'complicated', 'maintained', 'limitation', 'ensures', 'introduce', 'intent', 'avoiding', 'tweek', 'aside', 'reaching', 'easiest', 'quicker', 'coalescing', 'todo', 'assumptions', 'trip', 'suppress', 'suggesting', 'combine', 'versus', 'altogether', 'irrespective', 'incase', 'recheck', 'straightforward', 'relying', 'extending', 'rework', 'recording', 'elx', 'retained', 'fly', 'improves', 'independently', 'mechanisms', 'wouldn', 'responsibility', 'truncate', 'verbosity', 'implication', 'mimic', 'natural', 'inspected', 'cacheless', 'guarantees', 'autonegotiation', 'allegiance', 'bypasses', 'outdated', 'enhancing', 'hopes']
#
# Cluster 26
# ['rev', 'channel', 'controller', 'network', 'intel', 'interface', 'vendor', 'adapter', 'fibre', 'cna', 'vpd', 'features', 'onboard', 'ethernet', 'enclosure', 'identifier', 'eth', 'external', 'provider', 'esb', 'vasa', 'uefi', 'technology', 'qlc', 'mass', 'usb', 'fsb', 'claimed', 'sfps', 'express', 'xeon', 'assembly', 'pro', 'compatibility', 'ent', 'identification', 'json', 'stepping', 'downstream', 'ssn', 'prometheus', 'tachyon', 'zfs', 'canister', 'dust', 'bundle', 'ivybridge', 'devil', 'pcix', 'connector', 'architecture', 'differs', 'gbe', 'compliant', 'oem', 'native', 'queried', 'property', 'unqualified', 'slotid', 'riser', 'incompatible', 'branded', 'flashed', 'transmitting', 'isa', 'centerpanel', 'oban', 'website', 'lightpulse', 'ebod', 'avago', 'formats', 'vital', 'interconnect', 'genuineintel', 'cmic', 'fbd', 'optics', 'imb', 'quoted', 'broadcom', 'oui', 'identity', 'controlling', 'supptd', 'vend', 'technologies', 'mesa', 'fcode', 'powerpath']
#
# Cluster 27
# ['irq', 'queued', 'harrier_interrupt', 'tpd_alloc', 'tpd_free', 'drq_done', 'ea_cpy_req_done', 'os_free', 'impl_tpd_log', 'har_dest_int_rpc', 'tdrv_do_isr_isrctx', 'link_bcast_recv', 'validate_process', 'ea_recv_panic', 'eagle_rcv_admin_int', 'ea_bwquota_send', 'bq_send_req', 'eagle_cpy_req', 'emfc_do_intr_handler', 'llss_isr_msix', 'chio_drq_done', 'ea_bkdr_recv', 'cluster_timer_work', 'har_admin_intr', 'tpd_clus_timer', 'vio_pcicmp_xcb_cb', 'eapm_cpy_done', 'har_src_int_loc_dma', 'elist_rm', 'gfc_isr', 'ocs_hal_process', 'slog_xcb_done', 'lckevt_clock_timeout', 'ocs_hal_cq_process', 'llss_init_io_done', 'llss_initiator_reply', 'pdio_local', 'ea_sys_cmd_hdler', 'tdrv_xcb_exec_pri', 'eagle_request_data', 'ocs_gfc_hal_intr', 'ea_do_cpy_req', 'bq_promote_defer_mtx', 'ea_mmove_barr_done', 'tpd_sys_krn_hook', 'ealink_timer', 'ea_cpy_setup_req', 'eacmd_get_rrc', 'ea_xor_xcb_cb', 'cluster_node_down_cb', 'tpd_timeout', 'cluster_do_ndown_cb', 'har_xcb_exec_pri', 'clus_timer_send_val', 'har2_error_intr', 'emfc_cdb_handler', 'ea_call_request', 'osp_irq_normal', 'eagle_system_cmd', 'ea_xcb_dif_cb', 'ea_move_reply_cb', 'osprey_interrupt', 'eacpyxor_xcb_done', 'emfc_tgt_proc_iocb', 'ea_node_down_defer', 'tpd_mutex_exit_irq', 'tdrv_do_thdctx', 'emfc_dispatch_cdb', 'ocs_gfc_hal_io_cb', 'ea_xor_do_callback', 'fpga_isr', 'eaipc_listen_phandle', 'tpd_dispatch_arg_cb', 'har_src_int_mem_dma', 'gfc_tgt_io_cb', 'ipckrn_reply', 'ea_reqdata_reply_cb', 'lckevt_start_clock', 'ea_msgcmd_free_reply', 'tpd_exit_event', 'ipckrn_listen', 'sdt_get_lba_params', 'tpd_timer_event', 'har_link_hw_regs', 'tpd_snprintf', 'rdsrv_response', 'har_mir_flush_link', 'rec_create_diag', 'pfail_sublck_save', 'tpd_get_ksymbol', 'ea_fst_move_reply_cb', 'fcrc_done', 'vio_rec_rbmap_isr', 'ldio_retry_timeout', 'ealink_reset_link', 'llss_isr_msix_cb', 'validate_start', 'validate_restart', 'har_send_admin', 'tpd_timer_cb', 'scsi_cmnd_done', 'sdt_post_scsi_error', 'tpd_get_board_series', 'stats_count', 'join_periodic_work', 'ea_alloc_req_buff']
#
# Cluster 28
# ['data', 'write', 'block', 'read', 'full', 'verify', 'dif', 'blocks', 'corruption', 'pattern', 'writing', 'writes', 'miscompare', 'expect', 'lba', 'crc', 'garbage', 'reads', 'written', 'overwrite', 'fill', 'parity', 'compare', 'backend', 'compressible', 'prefill', 'incompressible', 'partial', 'filled', 'section', 'integrity', 'expecting', 'odd', 'overwriting', 'portion', 'zeros', 'offsets', 'ats', 'homogenous', 'filling', 'factor', 'stripe', 'boundary', 'compareutil', 'mis', 'reconstruction', 'guarantee', 'comparing', 'uncompressed', 'zeroes', 'patterns', 'succeeds', 'transferred', 'corruptions', 'miscompares', 'walking', 'observation', 'container', 'rewrite', 'zeroing', 'homogenous_data', 'sequentially', 'collisions', 'corrupting', 'reconstructed', 'discarded', 'transfers', 'reconstruct', 'verifies', 'similarly', 'dedupable', 'preread', 'compares', 'cross', 'overlapping', 'resides', 'stepset', 'fills', 'randomized', 'apptag', 'overwrites', 'rebuilt', 'boundaries', 'reread', 'lbas', 'viewed', 'rewrites', 'readback', 'eabkdoor', 'patroller', 'checkvvopts', 'stripes', 'rewritten', 'ntfs', 'occasional', 'corrupts', 'divided', 'stepsize', 'recompute', 'extents', 'pfsv_write_to_ide', 'containers', 'miscompared', 'unintentionally', 'aftermath', 'curves', 'check_buff', 'checkvvonly', 'm_in_blocks']
#
# Cluster 29
# ['devtype', 'mag', 'layout', 'createcpg', 'ssz', 'showspace', 'avail', 'cap', 'thin_growcmd', 'msgtype', 'createald', 'sdg', 'refcnt', 'cleanonly', 'snapcpg', 'rawfree', 'cavail', 'rowsz', 'setsz', 'cpsd', 'stepkb', 'rsizemb', 'basecpg', 'ddvv', 'usablefree', 'cpsa', 'setsize', 'basessd', 'ddcpg', 'characteristics', 'snapspace', 'createflashcache', 'thin_grow_retry_th', 'desperation', 'sdgs', 'aaa', 'vvsize', 'cleanfree', 'blk_after_refcnt', 'creationpattern', 'foo', 'tpd_version', 'scm', 'createld', 'node_count', 'ssd_count', 'fc_count', 'nl_count', 'host_count', 'tunenodech', 'dddvv', 'ddinteraction', 'dev_type', 'devtype_ssd', 'raidtype', 'sortcol', 'no_stale_ss', 'cageid']
#
# Cluster 30
# ['term', 'opcode', 'reading', 'ignore', 'sector', 'transport', 'vadm', 'medium', 'vv_', 'seek', 'errno', 'canceled', 'end_request', '2', 'ea_process_down', 'caught', 'decompression', 'vname', 'sccmd_docdb', 'eaipc_listen', 'acpi', '1', '2016', '5', 'wrt', '00000026', 'jbd', 'gpe', 'segfault', 'eaipc_sys_reason', '4', 'parse', '2015', '3', '8', 'insufficient', 'divide', 'garbage_collector', '6', 'ext3_put_super', 'evaluating', '2014', 'ae_not_found', '0x3', 'recoverable', '2017', 'erased', 'unrecovered', '2013', 'saver', '9', '2009', '10', 'namespace', '11', 'isp', '23', 'retryable', 'getportdev', 'vvcmd_drain_ddc', 'adm_read_pg', 'scsi_dump', '0x18', 'iob', '7', '16', 'sqlite', 'iterating', 'dump_dev_read', 'psargs', 'fulldef_new_vol', '3par', 'gigeth_mon', 'rcba', '0x9', 'do_divide_error', '_gpe', '0x1', 'bio', 'ext3_new_inode', '18', '0x5', 'psparse', 'blk_update_request', 'dprint', 'l1', 'evgpe', '2011', 'repetitive', 'toerr']
#
# Cluster 31
# ['recdone', 'dup_relog', 'vvol_fulldefine_task', 'vvol_predefine_task', 'lru_clean_hdrs', 'sensedata', 'diskpos', 'lba_lsw', 'lru_clean_hdr', 'cons', 'vvol_drop_adm_op', 'set_state', 'vvol_drop_adm_proc', 'weezer', 'vvol_drop_adm_task', 'switch_to', 'vvol_drop', 'migratetype', 'queen', 'vol_rec_async', 'clus_bcast', 'iocbcmd', 'vvol_flush_this_vvol', 'stm', 'out_of_memory', '__bad_area', 'other_vv', 'sizz', 'removevluns', 'rbtracker', 'vandros', 'pfrec_end', 'fujitsu', 'state_link_err', 'vv_cast', 'other_meta', 'vvmasterid', 'cmp_dcow_pagin', 'getvsize', 'sysrqpanic', 'mcjbt_tty', 'snapssd', 'max_intr_time', 'pex_fat_ferr', 'tmm', 'sd_snp', 'reversing', 'pchinitpeim', 'mccoy', 'inj_fatal_smi', 'ize', 'sii', 'vol_rec_vvol', 'ferr_global', 'clus_recn_ndown', 'dif_valid', 'testcleanup', 'cmp_opvio_index', 'rcdtdregionmovesync', 'sdd', 'removeall', 'norm', 'ddd_rd_done', 'missing_credit', 'styx', 'portfailoverenabled', 'mcnet_waitnodechange', 'replnhd', 'ldsk_rset_pinned', 'do_ioctl', 'rec_replay_rep_rmm', 'cpuiopei', '__bootstrap', '__bootstrap_inner', 'vio_rmt_rd_xcb_cb', 'mangmain', 'thin_savings', 'cachemergequal', 'alloc_pages_vma', 'cur_phase', 'sysrqpanicrandomnode', 'llfc', 'rcpy_fw_last_pm', 'op_up', 'afterrecover', 'cars', 'setportfailover', 'nohz', 'enableepic', 'fail_cmp_dcow_pagin', 'get_io_apic_vector', 'vvol_del_commit', 'lasthdr', 'atanasof', 'removecascade', 'tpd_thdpool_gpoolcb', 'iiodmiinitpeim', 'capsulepei', 'errors_on_a_port', '0xc9', 'getusercpg', 'alloc_pages', 'sde', 'check_log_leak', 'jknibbe', 'nr_to_cal', 'move_back_chunklet', 'derr', 'qlfc_fail_crc', 'gatling', 'davies', 'bios_kernel_hba', 'op_down', 'sdj', 'pptbl', 'startio', 'bucket_link', 'vreq_src_vv_dl_compr', 'nr_t', 'vvretentiontimemax', 'zero_eapfn', 'adm_mstat', 'yagi', 'max_pgcount', 'yonder', 'eagle_isr_error', 'pchspipeim', 'nll', 'list_link', 'vol_base_close_flush', 'sysinfo', 'release_console_sem', 'mctp_compact', 'stoppin', 'startpin', 'sysmgrlog', 'simplepowercycle', 'fabricdb', 'mclp_reset_loadfw', 'isns', 'ch_io_beg', 'mc_sysmgr_dar_ready', 'prev_state', 'prerr', 'ldsk_rset_playback', 'ticket_init', 'notsynced', 'cmp_tick_loop', 'coremanagement', 'alloc_pages_current', 'sdl', 'sdm', 'vol_dcow_add_log', 'union', 'is_master', 'gc_allowed_nodes', 'rdev_read', 'secure', 'simpsjes', 'boardidchimeranode', 'mpress', 'hostpresentallluns', 'linux_gcbdev', 'crc_collision_data', 'excp_ptbl_flush', 'diskscrub', 'coracle', 'vol_base_close_final', 'updatevvpanic', 'ret_off', 'mc_getkmemval', 'sizee', 'cback_ptr', 'grow_exist_vv', 'kernal', 'testcpg', 'batch_evtq_th', 'upgradenote', '__kwargs', 'p_count', 'basenl', 'link_hs', 'rpe', 'compl', 'rcs', 'ticket_config', 'cmp_dirty_flush', 'rec_req_proc_sr', 'createpcopyofasync', 'sdn', 'fpvv', 'unbal', 'cback_func', 'atf_periodic', 'get_sysmgr_params', 'fourier', 'errstats', 'load_fc', 'load_ssd', 'mclb_pmctab', 'accepts', 'amb', 'te_pathrst', 'chunk_off', 'llss_init_sick_check', 'drq_hstlog', 'diskload', 'chaos', 'wrmsk', 'nonestate', 'usr_func', 'difsnap', 'sdk', 'rcstartstopperiodic', 'ocs_list', 'ecp_list', 'async_cb', 'chkarg', 'toggles', 'unload_excp', 'initdone', 'rig', 'cur_state', 'nguyen', 'mang_pfail', 'skipchecks', 'ldmap', 'pfail_wait_needed', 'phyreceivererror', 'vmwarecluster', 'cur_nm', 'nodefailover', 'compression_none', 'nupdown', 'ea_crc_req_done', 'clrsrc', 'lru_crc_hdr', 'sdq', 'synchronizations', 'rdms', 'interruption', 'dedupnodedown', 'admoff', 'chkinterval', 'ret_from_intr', 'vansluish', 'vr_error', 'emfc_fabric_maxlife', 'partly', 'hetero', 'esxcfg', 'xcb_size_shift', 'print_buffer', 'pfrec_rmt_info_', 'dev_name', 'evtgen', 'mcvv_tune', 'coremanman', 'strategies', 'lru_dedup_proc_hdr', 'eagle_xcb_exec', 'single_ndown', 'compr_ss_ro', 'mc_callerid', 'snapparentunpres', 'compr_gc_init', 'cmp_do_realloc', 'woodland', 'v_last_ssr_attempt', 'snmpagent', 'mirror_shutdown', 'dcow_ro_cow', 'rsphdr', 'r_to_call', 'alloc_hint', 'roff', 'recurred', 'panic_vv_master', 'dskboff', 'dds_allow_ ...
#
# Cluster 32
# ['link', 'reason', 'current', 'bad', 'unknown', 'view', 'subsystemstatusretry', 'protocol', 'final', 'traffic', 'seq', 'tie', 'breaker', 'entering', 'pause', 'quorum', 'entered', 'forcing', 'reach', 'forwarding', 'transition', 'killing', 'ticks', 'cluslog', 'propagating', 'ser_link_state_ndead', 'learning', 'clusbk', 'task_running', 'reqdump', 'activate', 'rmw', 'tks', 'link_up', 'bklnk', 'config_wait', 'por', 'abnormal', 'bklnk_state', 'pending_reset', 'lsm', 'lnk_rec_en', 'participate', 'shootdown', 'enters', 'rcv_msg', 'get_comp_spn_switch', 'spn', 'wipe_needed', 'repl_vv', 'ea_link_up', 'funky', 'qlcna_common', 'link_prv_state', 'link_error', 'link_down', 'ldev', 'pltrst_pbg_oki_n', 'transmitter', 'inuse', 'node_not_normal', 'pon', 'vmas_adm_drop', 'initiative', 'logged_in', 'pdata_pdsld_stop']
#
# Cluster 33
# ['time', 'run', 'following', 'panics', 'first', 'seen', 'hit', 'two', 'times', 'minutes', 'another', 'multiple', 'occurred', 'ran', 'second', 'took', 'happened', 'many', 'around', 'within', 'taken', 'failures', 'seeing', 'tried', 'every', 'hours', 'several', 'taking', 'runs', 'saw', 'initial', 'couple', 'hour', 'injections', 'monitor', 'minute', 'observed', 'takes', 'three', 'iteration', 'follows', 'repeated', 'twice', 'almost', 'repeat', 'iterations', 'mins', 'occured', 'hits', 'resulted', 'stalls', 'crashes', 'repeatedly', 'heavy', 'occurring', 'continued', 'seemed', 'appeared', 'approx', 'approximately', 'experienced', 'stops', 'third', 'began', 'excessive', 'consistently', 'parallel', 'cored', 'jammer', 'generates', 'stayed', 'continuously', 'apart', 'observe', 'five', 'constantly', 'hrs', 'crits', 'repeating', 'throughout', 'induced', 'numerous', 'injects', 'ten', 'unsuccessful', 'kills', 'encounters', 'resumes', 'stalling', 'executions', 'powerfailed', 'story', 'orions', 'ndoe', 'eventual', 'idles', 'config_lock', 'sluggish', 'lying', 'fixblock', 'shutdowns']
#
# Cluster 34
# ['headline', 'testcase', 'test_end', 'recoverfromfailure', 'ddprocesslogpages', 'cmprpanics', 'pfailregionmove', 'ddorphanpanic', 'ddrandompanics', 'test_begin', 'onlinevvcopy', 'cmprowoneblockpanic', 'biglunrandom', 'pindata', 'vvonlineconversion', 'dddoubledown', 'cmprfullvvowpanics', 'quickjbodpowercycle', 'vvconversionpanic', 'greg', 'pfailsimpleinject', 'author', 'ddbasics', 'onlinepromotesv', 'tpdunittests', 'meanlunrandom', 'pfailnodedownrecover', 'ddpanics', 'beupdatepd', 'beshutdown', 'powerbumptest', 'rcsteadyasync', 'batterydraintest', 'cmprnpageowpagepanic', 'zerowrite', 'onlinepromotesvpanic', 'onlinevvcopypanic', 'cmprnpageowpage', 'rcdtdpanicssync', 'ddcompactcpg', 'pfailstaggeredinject', 'ddmangler', 'lunrandom', 'rcdtdpanicsasync', 'bemalicioushotplug', 'nalder', 'mergequal', 'ddgcnodes', 'tpbasics', 'sncbasics', 'randomhotplug', 'cmprfullvvow', 'vvsnapshotcreation', 'ddwritecache', 'ddjunkie', 'rcsteadysync', 'cmprtargetediopanics', 'cmprpfailrecover', 'rcsyspanicsperiodic', 'cmprtargetedio', 'ddgrowvv', 'pf_test', 'fcachelunrandom', 'rcshutdownnodeasync', 'rcsyspanicssync', 'cmprerrortest', 'bootdiskattack', 'beupdatepdfcache', 'cmprowoneblockxpage', 'pfailrloginject', 'ddabandon', 'cmprvariableratio', 'befailover', 'bemergequal', 'dddryrun', 'pfailrandomsecondary', 'rcsteadyperiodic', 'rcmergequal', 'printbox', 'rcsyspanicsasync', 'cmprowoneblock', 'snconlineupgrade', 'rcshutdownnodesync', 'saspathcroup', 'ddbathwater', 'join_suite', 'ddgcpanics', 'powercyclebasher', 'beporthavoc', 'behotinterval', 'rcdtdpanicsperiodic', 'diskoinferno', 'ddorphan', 'dddumpster', 'kernelpanic', 'powerupnodeinterval', 'errors_on_b_port', 'rcdtdregionmoveasync', 'dtd_tests', 'morauske', 'cmprsdmetack', 'defragpanics', 'rcasyncssmnodedown', 'scsicache', 'rcstartstopsync', 'powerrailtests', 'rcasyncwriteordering', 'ddzerowrite']
#
# Cluster 35
# ['session', 'lckstp', 'vmunix', 'invoke', 'loading', 'deadnid', 'xcbq_shutdown', 'eaipc', 'journal', 'efi', 'eapa', 'igb', 'caching', 'peim', 'callbacks', 'suppressed', 'loginit', 'flow', 'owner_rmm', '__ratelimit', 'configuring', 'mir_size', 'kjournald', 'meapa_start', 'meapa', 'profile', 'syslogd', 'ordered', 'routers', 'savelog_start', 'cluster_join_fail', 'ea_int', 'ea_src_int', 'rec_replay_rep_mb', 'vaddr', 'max_cached_pgs', 'rlog', 'enodecee', 'em_logs', 'meapa_end', 'lent', 'oustanding', 'sublck', 'savelog_stop', 'open_alt', 'touching', 'pref', 'clocksource', 'rec_copy_repl_taglog', 'pfrec_load_crdt_info', 'num_dmas', 'cpupeim', 'batlife', 'srcs', 'max_dirty_cnt', 'protreq', 'ea_fst_data_req', 'wdog', 'tsc', 'crdt_count', 'eagle_patrol', 'acfail', 'acgood', 'nport', 'eos_state', 'rc_timeout', 'clocksource_failover', 'tpd_vv_block', 'ea_sys_powerfail', 'takeover', 'inetutils', 'debouncing', 'hsack', 'rmtickinformer', 'protack', 'hsrecv', 'protack_recv', 'hsdata', 'hsack_recv', 'nodegb', 'rm_xmit_rti', 'recns', 'millisecond', 'recn_masks', 'debounce', 'cnvm_enable_backup', 'check_period', 'pinld_do_read', 'clus_nup_sync_reply', 'pfail_nvdimm_arm', 'eabarrier', 'next_interrupt', 'volmanager', 'r_rdy', 'ioctl_disable_vport', 'subroutine', 'g_port']
#
# Cluster 36
# ...
#
# Cluster 86
# ['hat_vol', 'vv_rec', 'dedup_dumper', 'adm_vol', 'compr_thread', 'dcow_handler', 'dop', 'pfail_rec_thr', 'pfrec_do_phase', 'vol_compr', 'vvol_close_op', 'compr_vv_thread', 'pfrec_rec_logs', 'vvinfo_free', 'meta_comm', 'ddd_io_write', 'logq', 'do_excp_tte', 'vio_name_wr_cmps', 'vv_node_down_srv', 'rec_replay_rep_logs', 'cmp_do_cow', 'rec_replay_rep_vv', 'rmt_wait', 'thrd_type', 'cmp_exist', 'ddd_handler', 'vvhash', 'vio_fast', 'cmp_mk_new_page', 'rec_cmp_lookup', 'cmp_pagin_dcow_base', 'lcmp', 'fid', 'rec_req_proc_srv', 'vv_node_down_sr', 'compr_main_loop', 'excp_create', 'do_walk_dptp', 'ddd_dedup_handler', 'pfrec_setup_rcmp_log', 'pfrec_build_logs', 'rec_cmp_dup_cb', 'excp_map_add', 'alloc_rec_req', 'local_only', 'vv_cnt_update', 'ddd_proc_dedup_pages', 'meta_proc_log_page', 'ddd_do_dedup_handle', 'pfrec_setup_rec_log', 'compr_process_vvq', 'adm_commit_bufbmap', 'excp_mod_tte', 'ldr_got_log_res', 'eagle_req_wait_comm', 'adm_alloc', 'alloc_rmp', 'dreq', 'mx_cmp', 'rec_get_reccmp', 'update_flc_dirty_cnt', 'ea_cleanup_all_msgs', 'clusquorum', 'rec_vv_cow_cmp', 'adm_finish_bufmap', 'vio_commit_logs', 'bq_ndown_cleanup', 'ddd_io_read', 'vv_owner_info', 'rmt_mirror', 'rec_owner_cmp_log', 'cmp_get_ddd_cmps', 'rec_cmp_rep_log', 'excp_map_lookup', 'pfrec_rmt_info_srv', 'rec_vv_rw_dcow', 'compr_clean_vv_hash', 'lck', 'rmp_free', 'vvol_remove_async', 'cmp_book_dirty', 'rmp_crd_isr', 'log_flag', 'rec_bmap_from_tte', 'rec_data_tte_bmap', 'is_excp_tbl_corrupt', 'ea_make_request_msg', 'dpgsz', 'rec_vv_ro_dcow', 'reque', 'vol_rec_mflush', 'ddd_new_dedup_page', 'ddd_crc_handler', 'ddd_handle_new_dedup', 'eagle_validate_dif', 'cmp_do_compr_cow', 'alloc_anon_dskcmps', 'hat_unload_vol', 'hat_rec_rst_adm', 'excp_create_dcow', 'rec_handle_cmp_log', 'mpg_update_loglist', 'compr_cachepg_hashin', 'meta_update_log_page', 'rec_bulk_dup_cmps', 'lru_id', 'rec_vv_dirty_cmp', 'rm_async_vv_resp', 'tpd_rmlink', 'cmp_rec_start', 'vol_rec_master', 'excp_get_new_tag', 'meta_gc', 'relog_rep_cmp_cb', 'norm_tte_to_vtag', 'pfrec_get_rcmp_info', 'wait_anchor_done', 'excp_pgin_dptp', 'nblk_lock_cmp', 'vreq_dnhd', 'vv_master_lookup', 'unlock_vvhash', 'compr_read_ios_done', 'eagle_dif_req_wait', 'pfrec_load_data', 'compr_process_workq', 'gc_proc_tte', 'pfrec_get_repl_cmp', 'rec_excp_for_dcow', 'cmp_log_mod_cmps', 'rec_meta_rep_log', 'adm_nxt_bmap_pg', 'adm_alloc_bmap_pg', 'meta_clear_rec_lp', 'hat_clear_rec_lp', 'adm_find_rbmap', 'inc_busy', 'excp_flush_cb', 'nbuf', 'tpd_rmlink_fc', 'cmp_get_crc_cmps', 'rmt_admvv_alloc', 'calc_cmp_crcs']
#
# Cluster 87
# ['cpu', 'interrupt', 'interrupts', 'hung', 'cpus', 'soft', 'usec', 'caller', 'idle', 'lockup', 'watchdog', 'softlockup', 'processor', 'kdb', 'nmi', 'scheduler', 'isr', 'irqlog', 'gfc', 'lockups', 'regularly', 'hrtimer', 'xcbs', 'ppid', 'runq', 'intr', 'eaisr', 'yield', 'irqlogs', 'intsrc', 'processors', 'timers', 'emfc_task_thread', 'softlockups', 'firing', 'hbs', 'mdma', 'virt', 'usecs', 'storm', 'watchdog_timer_fn', 'hogging', 'srcint', 'tpd_cbios_sync', 'pegged', 'panic_cpu', 'wtchdg', 'hog', 'reentrent', 'sysgmr', 'timedout', 'ipi', 'shr', 'maskable', 'dog', 'clobbered', 'tss', 'ext_smi', 'vec', 'tpd_eagle_timer', 'this_cpu', 'relinquish', 'validations']
#
# Cluster 88
# ['dev', 'tpddev', 'filesystem', 'transition_thread', 'pfail_storage', 'mounted', 'raw', 'mount', 'ioload', 'altroot', 'coreman', 'tocs', 'pr_mnt', 'transitioned', 'mapper', 'dump_bdev', 'urandom', 'shell_status', 'stressd', 'fsck', 'pfailio', 'pr_svr', 'rdsk', 'alt', 'pfail_rec_pick_ide', 'rats', 'epoch', 'transitioning', 'slogld', 'detest', 'bdev', 'filesystems', 'slogclose', 'unmount', 'satisfy', 'myfs', 'sbin', 'test_tpvv', 'uncompresspc', 'prefix', 'sys_start_sloglds', 'tmpfs', 'umounted', 'unix', 'mounting', 'mnt', 'unmounted', 'pr_ide', 'intel_idle', 'umount', 'ufs', 'udev', 'tpd_vvadmin', 'acpi_hest', 'gennums', 'smartd', 'vmmgr_config', 'waitforprmount', 'admin_vol_check', 'scsi_cdb', 'deactivate', 'cdrom', 'hwinv', 'th_num', 'poweronsystem', 'weak', 'fdisk', 'frt', 'inodes', 'test_cpg', 'rds', 'mytpvv', 'swapoff', 'mtab', 'oseek', 'lseek', 'run_tests', 'hexdump', 'perror']
#
# Cluster 89
# ['running', 'testing', 'steps', 'systems', 'eos', 'setup', 'chimera', 'encountered', 'performing', 'titan', 'performed', 'stress', 'tornado', 'nightly', 'yaml', 'arrays', 'ironman', 'rcip', 'overnight', 'http', 'org', 'hazard', 'platforms', 'perf', 'unity', 'automated', 'iport', 'rerun', 'motion', 'clusters', 'import', 'inservs', 'mixed', 'soak', 'job', 'stations', 'downs', 'steady', 'longevity', 'loads', 'recreated', 'directional', 'federation', 'node_fail', 'custom', 'scalability', 'whilst', 'nodefail', 'streaming', 'exercise', 'carried', 'romulus', 'interop', 'recreation', 'bidirectional', 'disables', 'centaur', 'carrying', 'migrating', 'iometer', 'quadport', 'mainline', 'george', 'bench', 'coring', 'migrated', 'vclass', 'vdbench', 'generator', 'eastress', 'concurrently', 'awhile', 'bullseye', 'borrow', 'perturbation', 'standalone', 'ess', 'stages', 'diskfs', 'pnd', 'preparation', 'borrowed', 'uni', 'farm', 'iports', 'runnign', 'mmmt', 'migrations', 'runing', 'tbc', 'mazor', 'poc', 'compressdev', 'soaking', 'occasion', 'licenses', 'combo', 'admitphase', 'impairments', 'smb', 'sdreclaim']
#
# Cluster 90
# ['node', 'cluster', 'nodes', 'pfail', 'powerfail', 'master', 'reboot', 'missing', 'went', 'shutdown', 'join', 'lockstep', 'rebooted', 'failover', 'entire', 'paniced', 'rebooting', 'panicked', 'unresponsive', 'kill', 'recovered', 'crashed', 'died', 'followed', 'four', 'killed', 'expedition', 'brought', 'recn', 'shortly', 'whole', 'reboots', 'booted', 'member', 'multi', 'joined', 'rejoin', 'booting', 'recovering', 'became', 'stay', 'wiped', 'halt', 'wide', 'locksteps', 'alive', 'formed', 'joining', 'shut', 'wiping', 'panicking', 'panicing', 'cyclic', 'rejoined', 'dies', 'bringing', 'whacked', 'begins', 'surviving', 'joins', 'shoot', 'survive', 'communicating', 'death', 'boots', 'proceeded', 'integrating', 'deadnode', 'pfails', 'node_down', 'rejoins', 'uncontrolled', 'dying', 'survived', 'complain', 'cmm', 'shuts', 'shooting', 'forming', 'taglogs', 'rejoining', 'nodeup', 'suffered', 'rescued', 'integrates', 'kc_set_cnt', 'reintegrate', 'participating', 'nonmaster']
#
# Cluster 91
# ['total', 'cnt', 'skip', 'panic_task', 'pfail_panic_write', 'dtoff', 'tagoff', 'repl_write_cmps', 'os_cbios_os_panic', 'validate', 'dynamic', 'pfail_init_offsets', 'rec', 'num', 'lckstep', 'pilt', 'tck', 'heart', 'diff', 'beat', 'avenger', 'unc', 'url', 'adjusting', 'pfail_get_num_tags', 'printk', 'nupublk', 'nupexc', 'unblk', 'dds_flush_for_close', 'quality', 'comexc', 'resret', 'nupret', 'rec_replay_rep_meta', 'tput', 'sysymgr', 'total_tags', 'owner_tags', 'credit_tags', 'other_tags', 'sysa', 'wls', 'next_inj_num', 'nodisks', 'pend_panic_cnt', 'howlong', 'trigger_pfail', 'alternating', 'rm_config_shutdown', 'pf_dblk_sz', 'power_off', 'call_console_drivers', 'fun', 'complaints', 'ics', 'startgroups', 'msg_log_level', 'fin', 'olugcommonlib', 'inj_now', 'bq_shutdown_complete']
#
# Cluster 92
# ['using', 'used', 'use', 'field', 'default', 'option', 'specified', 'supported', 'options', 'ratio', 'allowed', 'parameter', 'types', 'policy', 'unmap', 'method', 'parameters', 'display', 'settings', 'standard', 'qos', 'ids', 'displayed', 'tcl', 'spec', 'availability', 'minimum', 'store', 'sizes', 'limits', 'names', 'estimated', 'supports', 'specify', 'formatted', 'columns', 'rules', 'expiration', 'comparison', 'variables', 'spc', 'desired', 'ssmc', 'ratios', 'displays', 'usable', 'choose', 'modification', 'flashcache', 'getvv', 'specifies', 'deprecated', 'gui', 'optimal', 'units', 'write_same', 'integer', 'afc', 'members', 'definitions', 'attribute', 'simulation', 'blocksize', 'constant', 'interfaces', 'sanity', 'reduction', 'chosen', 'specification', 'filtering', 'setsys', 'rename', 'edit', 'slicing', 'calculations', 'thresholds', 'compute', 'savings', 'trim', 'modes', 'expose', 'mappings', 'relies', 'override', 'defaults', 'alter', 'optional', 'layouts', 'emulate', 'getcpg', 'dynamically', 'human', 'devtypes', 'combinations', 'simpler', 'inspecting', 'alternatively', 'spaces', 'personaprofile', 'choosing', 'properties', 'sam', 'spd', 'configurable', 'overview', 'chunking', 'configures', 'ieee', 'hardcoded', 'specifier', 'ascertain', 'get_lba_status', 'subcommand', 'language', 'replaces', 'speeds', 'qpsraw', 'utilize', 'operand', 'globally', 'allowable', 'practices', 'truncation', 'sansurfer', 'omit', 'pinpoint']
#
# Cluster 93
# ['tocsvr', 'map', 'opt', 'proc', 'bin', 'exe', 'smp', 'vmlinux', 'rwxr', 'ixgbe', 'scsid', 'mdio', 'gcore', 'pmfg', 'tpdld', 'tld', 'ict', 'dmpio', 'events_nd', 'mkdir', 'compile_dir', 'compile_host', 'aer', 'kerntypes', 'modmaps', 'pfsuper', 'darsvr', 'defs', 'kdoan', 'nfsnobody', 'ssl', 'load_host_os_defs', 'srsampler', 'tape', 'maxmem', 'corefiles', 'rescaled', 'sysmgr_fullsync', 'crashrc', 'swoosh', 'rwx', 'pcore']
#
# Cluster 94
# ['usr', 'snp', 'lim', 'vsize', 'srdata', 'prov', 'rsvd', 'detailed_state', 'bsid', 'copyof', 'mib', 'wrn', 'sizemb', 'warn', 'showcpg', 'wthru', 'efficiency', 'compaction', 'usedmb', 'lgct', 'lgid', 'mapv', 'tot_rsvd', 'compact', 'dttes', 'hostwr', 'mstr', 'sncp', 'nextdc', 'prnt', 'roch', 'rwch', 'snapmb', 'pblkremain', 'admmb', 'pprnt', 'usermb', 'system_cpg', 'rc_usage', 'basevv', 'cpgalloc', 'udid', 'usrcpg', 'snpcpg', 'datareduce', 'dart_vv', 'getcompr', 'cap_efficiency', 'overprov', 'uniqcrcs', 'vv_wwn', 'overprovisioning', 'tptype', 'vvprom', 'vm_tdvv', 'tpvv_uncompr', 'bjhaotpvvcomp', 'size_mb', 'ddomain', 'bigvv', 'ldfree', 'auto_check', 'tdvvddssz', 'regcnt', 'aocfg', 'snp_rsvd_mb', 'sprnt', 'tpddebuglog', 'need_check', 'showvv_', 'fs_cpg', 'vsize_mb', 'getcpgind', 'sag', 'cpgname', 'virtualsize', 'atpvv', 'rcopystatus', 'tdvvddcsz', 'sanity_check_pfpart']
#
# Cluster 95
# ['secs', 'nup', 'loc', 'dst', 'spent', 'vva', 'abt', 'viosrv', 's_p', 'remap', 'srv', 'recvd', 'aln', 'com_exc', 'res_ret', 'fsecs', 'set_loglimit_rec', 'tablect', 'tableidx', 'rel', 'sleept', 'hires', 'stick', 'owner_vv', 'owner_meta', 'relogrodcows', 'relogrwdcows', 'relogzerodcows', 'rows', 'duprodcows', 'duprwdcows', 'dupzerodcows', 'rsrv', 'recvd_dds_ec', 'bullock', 'dup_dds_ec', 'tins', 'waitfordrivestate', 'msecs', 'hintinvdcows', 'compresssed', 'ldpd_drq', 'tcur', 'lseq', 'dump_buffer', 'ardcb', 'flgs', 'blkq', 'cputk', 'duprozerodcows', 'relogrozerodcows', 'gps', 'vvld_total', 'ldpd_total', 'cfg_link', 'tget', 'tcomp', 'checklogforerror', 'lcl', 'exc', 'no_xri', 'invalid_rpi', 'correlates', 'vb_dds_ec_inv_proc', 'start_reg', 'tv_sec']
#
# Cluster 96
# ['administrative', 'lds_not_started', 'reg_ioctlsrc', 'backing', 'aka', 'formfactor', 'hundreds', 'reasoning', 'havent', 'observing', 'cold', 'intend', 'watching', 'occupied', 'reside', 'nts', 'ordinary', 'possibilities', 'orange', 'exhibit', 'concept', 'jumped', 'pfrec_post_relog', 'dedupped', 'difficulty', 'legal', 'theoretically', 'opposite', 'evident', 'seven', 'snaptreelimits', 'distinct', 'rarely', 'furthermore', 'perky', 'equally', 'viable', 'plugging', 'thsi', 'kinda', 'comparable', 'pure', 'infrequently', 'officially', 'remembered', 'involvement', 'jumps', 'aren', 'misbehaving', 'enc', 'fnprdsrv', 'plank', 'tend', 'sits', 'indirectly', 'struggling', 'gradually', 'nope', 'shares', 'suffer', 'flowing', 'shape', 'everybody', 'jerry', 'facts', 'phantom', 'wanting', 'lunch', 'tx_timeout', 'conflicting', 'fpgs', 'hds', 'cope', 'accounts', 'heading', 'faced', 'managing', 'originated', 'chips', 'reconfigure', 'agian', 'logld', 'merrill', 'sufficiently', 'underruns', 'alternatives', 'msft', 'toward', 'eyes', 'serves', 'improving', 'unexplained', 'manages', 'beats', 'experiences', 'bursts', 'busted', 'targetba', 'offender', 'restrictions', 'upping', 'cindy', 'sparse', 'holiday', 'varied', 'comparisons', 'unplugged', 'nokia', 'messing', 'mulitple', 'unread', 'buy', 'classic', 'backs', 'drivephybounce', 'promptly', 'experimenting', 'thousand', 'conclusively', 'unzoned', 'legitimately', 'barely', 'semi', 'sensible', 'flavors', 'polyserve', 'consisted', 'breakdown', 'bearing', 'underneath', 'talks', 'overly', 'trial', 'apps', 'behotplug', 'chart', 'debug_misshb', 'nine', 'vm', 'poke', 'pertaining', 'dangerous', 'isolating', 'ugly', 'flaky', 'unplug', 'vios', 'door', 'grapesofsas', 'chunkets', 't', 'ariba', 'hammer', 'fraction', 'acted', 'luckily', 'qfulls', 'urgently', 'overwhelmed', 'peculiar', 'overloading', 'uncommon', 'characterize', 'manifested', 'angle', 'notable', 'beforehand', 'arbitrary', 'significance', 'oss', 'der', 'frozen', 'maxed', 'clarified', 'prime', 'futher', 'taht', 'exhibited', 'pain', 'testbed', 'likes', 'pcache', 'relied', 'downloads', 'primarycomp', 'wallie', 'terminology', 'widely', 'variance', 'granular', 'compromise', 'degrading', 'wild', 'dozens', 'resultant', 'authorized', 'pdlib', 'contrary', 'tpvvei', 'coincides', 'ceased', 'hoped', 'prone', 'assessing', 'certainty', 'distinction', 'offhand', 'coincide', 'additonal', 'adverse', 'rapid', 'costa', 'personnel', 'spewing', 'heck', 'blew', 'ekstrom', 'serv', 'simulates', 'curtis', 'consequences', 'coordination', 'doable', 'disconnection', 'noti', 'wouldnt', 'miscabling']
#
# Cluster 97
# ['sherlock', 'delta', 'difference', 'waitforallvvsnormal', 'detailedstate', 'orion', 'synchronized', 'stirling', 'lowe', 'hockley', 'claude', 'toto', 'kildall', 'ohm', 'nyquist', 'reichelt', 'gibbon', 'naismith', 'fermi', 'bardeen', 'joy', 'issing', 'edison', 'mauchly', 'pasteur', 'ramones', 'kmfdm', 'genesis', 'fergason', 'forest', 'ledley', 'snapiothread', 'clapton', 'frampton', 'eagles', 'armstrong', 'casimir', 'ufo', 'bayes', 'watt', 'quiet', 'soucek', 'thompson', 'oasis', 'journey', 'police', 'eckert', 'kellogg', 'molotov', 'wilco', 'faces', 'lincoln', 'helmet', 'jolly', 'inxs', 'drew', 'coffey', 'zztop', 'dolby', 'ratt', 'ballas', 'flowers', 'magma', 'zepplin', 'meatloaf', 'jaquares', 'gogos', 'coldplay', 'emerson', 'openroad', 'strang', 'boston', 'abba', 'nirvana', 'removehost', 'shima', 'tompetty', 'pantera', 'colt', 'young', 'clienhost', 'kiss', 'ldisk', 'nyberg', 'sdmetacorrupt', 'printverbose', 'rush', 'slash', 'powerutil', 'vvblockfailurestatus']
#
# Cluster 98
# ['power', 'boot', 'become', 'loss', 'battery', 'cycle', 'everything', 'waitforinit', 'powered', 'restore', 'restoring', 'loops', 'turning', 'jbod', 'charge', 'restored', 'cycles', 'spin', 'batteries', 'cycled', 'powercycle', 'cut', 'controllers', 'milliseconds', 'powering', 'cycling', 'pfail_wipe_needed', 'letting', 'intentionally', 'jbods', 'drained', 'lights', 'induce', 'inaccessible', 'poweron', 'supplies', 'cutting', 'staggered', 'charging', 'glitch', 'serve', 'powercycled', 'succession', 'powers', 'knew', 'bounced', 'ac_good', 'powercycles', 'relay', 'circuit', 'fans', 'techs', 'becasue', 'interuptions', 'momentarily', 'dozen', 'ish', 'poweroff', 'dwell', 'settle', 'powercyclenode', 'nodeonlypowercycle', 'regulator', 'factory', 'c_str', 'skew', 'brownout', 'pcms']
#
# Cluster 99
# ['len', 'chunk', 'discard', 'xfrlen', 'bfact', 'ptype', 'patt', 'ccontrol', 'vvcp', 'oldest', 'ldname', 'newest', 'decode', 'vvoff', 'basevvs', 'ldid', 'choff', 'readonly', 'chnk', 'vvlen', 'normalpres', 'showblock', 'ldoff', 'trees', 'biglunmodel', 'mirrors', 'grp', 'createpcopy', 'growvv', 'transferblock', 'pdoff', 'contributes', 'lunname', 'normalunpres', 'pset', 'copy_failed', 'ldstep', 'snapparentpres', 'converts', 'thd', 'lunmodel', 'uuid', 'pdblock', 'vv_cur_nblock', 'ldblock', 'ccc', 'setstep', 'caw', 'convertinprogress', 'overcommit', 'bbb', 'createsnapof', 'uncomp', 'testld', 'unmatched', 'snappres', 'pcopyparentpres', 'formatpattern', 'incons']

# %%
g=open("word2vec_clusters.txt","w")
for cluster in range(0,num_clusters):
    words = []
    for i in range(0,len(word_centroid_map.values())):
        if( val[i] == cluster ):
            words.append(key[i])
    
    clusters =  ", ".join(words)
    g.write(clusters+"\n")
